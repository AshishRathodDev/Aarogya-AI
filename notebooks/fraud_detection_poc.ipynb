# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from typing import Dict, List, Any

# %%
# Set some display options for better readability in the notebook
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 20)
pd.set_option('display.width', 120)

print("Libraries imported and display options set.")
# Out:
# Libraries imported and display options set.

# %% [markdown]
# ## 1. Configuration: The Control Panel
#
# In a production system, these parameters would be loaded from an external file (e.g., `params.yaml`). This allows for easy updates without changing the code. For this proof-of-concept, we define them in a dedicated cell.

# %%
# Define the plausible biological ranges for various tests.
PLAUSIBILITY_RULES: Dict[str, Dict[str, float]] = {
    # Hematology
    "Hemoglobin":           {"min": 5.0, "max": 25.0},      # g/dL
    "Platelet Count":       {"min": 10000, "max": 1000000}, # /cumm
    "RBC Count":            {"min": 1.0, "max": 10.0},      # M/uL
    "WBC Count":            {"min": 500, "max": 50000},     # cells/cumm
    
    # Lipid Profile
    "Total Cholesterol":    {"min": 50, "max": 500},        # mg/dL
    "Triglycerides":        {"min": 30, "max": 1000},       # mg/dL
    "HDL Cholesterol":      {"min": 10, "max": 150},        # mg/dL
    "LDL Cholesterol":      {"min": 20, "max": 400},        # mg/dL
    
    # Liver Function
    "AST (SGOT)":           {"min": 5, "max": 500},         # U/L
    "ALT (SGPT)":           {"min": 5, "max": 500},         # U/L
    
    # Kidney Function
    "Creatinine":           {"min": 0.2, "max": 15.0},      # mg/dL
    "Urea":                 {"min": 5, "max": 200},         # mg/dL
}

# File paths
PROCESSED_DATA_PATH: str = '/Users/ashishrathore/Aarogya-AI/data/processed/master_health_data_v2.csv'

print("Configuration loaded.")
# Out:
# Configuration loaded.

# %% [markdown]
# ## 2. Core Logic: The Toolbox
#
# Here, we define our reusable functions. This modular approach is key to writing clean, maintainable, and testable code. Each function has a specific, well-defined purpose.

# %%
def load_and_clean_data(filepath: str) -> pd.DataFrame:
    """
    Loads the processed data and performs necessary cleaning and type conversion.
    """
    try:
        df = pd.read_csv(filepath)
        print(f"Successfully loaded {len(df)} records from {filepath}")
        
        if 'result' not in df.columns:
            raise ValueError("The 'result' column is missing from the CSV file.")

        # Convert 'result' column to numeric, coercing errors to NaN
        df['result_numeric'] = pd.to_numeric(df['result'], errors='coerce')
        
        # Report on cleaning
        initial_rows = len(df)
        df.dropna(subset=['result_numeric'], inplace=True)
        final_rows = len(df)
        print(f"Data Cleaning Report: Dropped {initial_rows - final_rows} rows with non-numeric results.")
        
        return df
        
    except FileNotFoundError:
        print(f"Error: The file was not found at {filepath}")
        return pd.DataFrame()

def find_plausibility_anomalies(df: pd.DataFrame, rules: Dict[str, Dict[str, float]]) -> pd.DataFrame:
    """
    Identifies records where test results fall outside plausible biological ranges using efficient pandas operations.
    """
    if df.empty:
        return pd.DataFrame()
        
    # Filter the DataFrame to only include tests for which we have rules
    df_filtered = df[df['test_name'].isin(rules.keys())].copy()
    
    # A lambda function to check if a value is within its rule's range
    def is_anomalous(row):
        rule = rules.get(row['test_name'])
        if rule:
            return not (rule['min'] <= row['result_numeric'] <= rule['max'])
        return False

    # Apply the function to find anomalies
    anomalies_mask = df_filtered.apply(is_anomalous, axis=1)
    anomalies_df = df_filtered[anomalies_mask].copy()
    
    # Prepare the final report dataframe
    if not anomalies_df.empty:
        anomalies_df['plausible_range'] = anomalies_df['test_name'].apply(lambda name: f"{rules[name]['min']} - {rules[name]['max']}")
        anomalies_df['reason'] = 'Result is outside the plausible range.'
        
        # Select and rename columns for a clean report
        report_columns = {
            'source_file': 'Source File',
            'test_name': 'Test Name',
            'result_numeric': 'Anomalous Result',
            'plausible_range': 'Plausible Range',
            'reason': 'Reason'
        }
        return anomalies_df[list(report_columns.keys())].rename(columns=report_columns)
        
    return pd.DataFrame()

print("Core logic functions defined.")
# Out:
# Core logic functions defined.

# %% [markdown]
# ## 3. Main Execution: The Factory Floor
#
# This is where we run the pipeline. We call our core functions in a logical sequence to produce the final result. The code here is simple and easy to follow because the complex logic is encapsulated within the functions above.

# %%
# 1. Load and clean the data
print("--- [Step 1/3] Loading and cleaning data... ---")
master_df = load_and_clean_data(PROCESSED_DATA_PATH)

if not master_df.empty:
    print(f"--- [Step 2/3] Analyzing {len(master_df)} clean records... ---")
    
    # 2. Deploy the Sentry to find anomalies
    print("Deploying The Sentry to find plausibility anomalies...")
    suspicious_reports_df = find_plausibility_anomalies(master_df, PLAUSIBILITY_RULES)
    
    # 3. Display the Sentry's report
    print("--- [Step 3/3] Generating Sentry Report... ---")
    if not suspicious_reports_df.empty:
        print(f"\n>>> 🚨 Sentry has flagged {len(suspicious_reports_df)} records! <<<\n")
        display(suspicious_reports_df)
    else:
        print("\n>>> ✅ Sentry reports: All clear! No plausibility anomalies found. <<<\n")
else:
    print("\n--- Pipeline stopped as no data could be loaded. ---")
# Out:
# --- [Step 1/3] Loading and cleaning data... ---
# Successfully loaded 1581 records from /Users/ashishrathore/Aarogya-AI/data/processed/master_health_data_v2.csv
# Data Cleaning Report: Dropped 152 rows with non-numeric results.
# --- [Step 2/3] Analyzing 1429 clean records... ---
# Deploying The Sentry to find plausibility anomalies...
# --- [Step 3/3] Generating Sentry Report... ---
#
# >>> 🚨 Sentry has flagged 48 records! <<<
#                                             Source File          Test Name  Anomalous Result  Plausible Range  \
# 14                 070a0bf186108bfd43470afab9738e32.jpg  Total Cholesterol      2.000000e+00         50 - 500
# 96    ilide.info-blood-report-pdf-pr_9a268b5250cb855...     Platelet Count      2.450000e+02  10000 - 1000000
# 143   ilide.info-blood-report-yatendra-08112022-pr_f...     Platelet Count      2.110000e+02  10000 - 1000000
# 204                                           WM115.pdf  Total Cholesterol      2.000000e+00         50 - 500
# 210                                           WM115.pdf          RBC Count      2.500000e+01       1.0 - 10.0
# 212                         TEST-REPORT-02.12.2022-.pdf      Triglycerides      1.153000e+03        30 - 1000
# 264   ilide.info-father-blood-test-report-sgrh-pr_c5...         Hemoglobin      1.000000e+00       5.0 - 25.0
# 338   ilide.info-max-lab-report-pr_37cb37b89df9e8ada...     Platelet Count      1.660000e+02  10000 - 1000000
# 351   ilide.info-lft-lalpath-pr_954f6d86d0a1283e1391...         AST (SGOT)      1.357900e+03          5 - 500
# 352   ilide.info-lft-lalpath-pr_954f6d86d0a1283e1391...         ALT (SGPT)      9.135000e+02          5 - 500
# 408                                             HDL.pdf     Platelet Count      1.500000e+02  10000 - 1000000
# 466                cc8898d38e6b5a27e0d0cb372e67fe2e.jpg    LDL Cholesterol      1.800000e+01         20 - 400
# 513   ilide.info-blood-report-pr_80a0516cb73bea9011a...  Total Cholesterol      1.000000e+01         50 - 500
# 514   ilide.info-blood-report-pr_80a0516cb73bea9011a...      Triglycerides      4.700000e+00        30 - 1000
# 515   ilide.info-blood-report-pr_80a0516cb73bea9011a...    HDL Cholesterol      4.700000e+00         10 - 150
# 516   ilide.info-blood-report-pr_80a0516cb73bea9011a...    LDL Cholesterol      4.700000e+00         20 - 400
# 621   ilide.info-blood-report-pr_0f79618c92430ffd441...     Platelet Count      2.950000e+02  10000 - 1000000
# 651                         2022_-TEST_REPORTS-_NEW.pdf      Triglycerides      4.446011e+09        30 - 1000
# 652                         2022_-TEST_REPORTS-_NEW.pdf    HDL Cholesterol      4.446011e+09         10 - 150
# 653                         2022_-TEST_REPORTS-_NEW.pdf    LDL Cholesterol      4.446011e+09         20 - 400
# 671   ilide.info-blood-test-pr_1682b457a4b7533ee17ae...     Platelet Count      2.280000e+02  10000 - 1000000
# 673   ilide.info-mr-arvind-yadavx27s-lipid-profile-l...      Triglycerides      2.014000e+03        30 - 1000
# 674   ilide.info-mr-arvind-yadavx27s-lipid-profile-l...    HDL Cholesterol      2.014000e+03         10 - 150
# 675   ilide.info-mr-arvind-yadavx27s-lipid-profile-l...    LDL Cholesterol      2.014000e+03         20 - 400
# 678   ilide.info-mr-arvind-yadavx27s-lipid-profile-l...          RBC Count      1.280000e+01       1.0 - 10.0
# 1131           656736796-20211010-Vijaya-Diagnostic.pdf  Total Cholesterol      1.000000e+01         50 - 500
# 1132           656736796-20211010-Vijaya-Diagnostic.pdf      Triglycerides      1.000000e+01        30 - 1000
# 1134           656736796-20211010-Vijaya-Diagnostic.pdf    LDL Cholesterol      1.000000e+01         20 - 400
# 1154  ilide.info-blood-report-pr_6c268d43f162f0ae71d...     Platelet Count      2.290000e+02  10000 - 1000000
# 1209  ilide.info-blood-test-pr_ec80bda54e669d364235f...  Total Cholesterol      2.000000e+00         50 - 500
# 1211  ilide.info-blood-test-pr_ec80bda54e669d364235f...    HDL Cholesterol      1.503700e+02         10 - 150
# 1214  ilide.info-blood-test-pr_ec80bda54e669d364235f...         Hemoglobin      1.000000e+00       5.0 - 25.0
# 1215  ilide.info-blood-test-pr_ec80bda54e669d364235f...          RBC Count      1.410000e+01       1.0 - 10.0
# 1272  ilide.info-keshav-kashyap-lipid-profile-pr_b06...    HDL Cholesterol      2.810000e+02         10 - 150
# 1316  ilide.info-d18240923-blood-report-pr_b363fe75d...     Platelet Count      2.450000e+02  10000 - 1000000
# 1376  ilide.info-blood-report-pr_490dfed05bb628bddef...  Total Cholesterol      7.600000e-01         50 - 500
# 1377  ilide.info-blood-report-pr_490dfed05bb628bddef...      Triglycerides      5.000000e+00        30 - 1000
# 1378  ilide.info-blood-report-pr_490dfed05bb628bddef...    HDL Cholesterol      7.600000e-01         10 - 150
# 1379  ilide.info-blood-report-pr_490dfed05bb628bddef...    LDL Cholesterol      1.770000e+00         20 - 400
# 1384  ilide.info-blood-test-report-pr_9032432fc3221d...     Platelet Count      2.610000e+00  10000 - 1000000
# 1443  ilide.info-s47-radha-diagnostics-gtroad-jhunsi...     Platelet Count      2.450000e+02  10000 - 1000000
# 1469  ilide.info-s47-radha-diagnostics-gtroad-jhunsi...     Platelet Count      2.450000e+02  10000 - 1000000
# 1478  ilide.info-mr-arvind-yadavx27s-lipid-profile-l...      Triglycerides      2.014000e+03        30 - 1000
# 1479  ilide.info-mr-arvind-yadavx27s-lipid-profile-l...    HDL Cholesterol      2.014000e+03         10 - 150
# 1480  ilide.info-mr-arvind-yadavx27s-lipid-profile-l...    LDL Cholesterol      2.014000e+03         20 - 400
# 1483  ilide.info-mr-arvind-yadavx27s-lipid-profile-l...          RBC Count      1.280000e+01       1.0 - 10.0
# 1574  ilide.info-cbc-lalpath-pr_ed43a0b419e257198a9b...     Platelet Count      9.200000e+01  10000 - 1000000
# 1580  ilide.info-erythrocytes-reference-dr-naini-set...         Hemoglobin      3.000000e+00       5.0 - 25.0
#
#                                       Reason
# 14    Result is outside the plausible range.
# 96    Result is outside the plausible range.
# 143   Result is outside the plausible range.
# 204   Result is outside the plausible range.
# 210   Result is outside the plausible range.
# 212   Result is outside the plausible range.
# 264   Result is outside the plausible range.
# 338   Result is outside the plausible range.
# 351   Result is outside the plausible range.
# 352   Result is outside the plausible range.
# 408   Result is outside the plausible range.
# 466   Result is outside the plausible range.
# 513   Result is outside the plausible range.
# 514   Result is outside the plausible range.
# 515   Result is outside the plausible range.
# 516   Result is outside the plausible range.
# 621   Result is outside the plausible range.
# 651   Result is outside the plausible range.
# 652   Result is outside the plausible range.
# 653   Result is outside the plausible range.
# 671   Result is outside the plausible range.
# 673   Result is outside the plausible range.
# 674   Result is outside the plausible range.
# 675   Result is outside the plausible range.
# 678   Result is outside the plausible range.
# 1131  Result is outside the plausible range.
# 1132  Result is outside the plausible range.
# 1134  Result is outside the plausible range.
# 1154  Result is outside the plausible range.
# 1209  Result is outside the plausible range.
# 1211  Result is outside the plausible range.
# 1214  Result is outside the plausible range.
# 1215  Result is outside the plausible range.
# 1272  Result is outside the plausible range.
# 1316  Result is outside the plausible range.
# 1376  Result is outside the plausible range.
# 1377  Result is outside the plausible range.
# 1378  Result is outside the plausible range.
# 1379  Result is outside the plausible range.
# 1384  Result is outside the plausible range.
# 1443  Result is outside the plausible range.
# 1469  Result is outside the plausible range.
# 1478  Result is outside the plausible range.
# 1479  Result is outside the plausible range.
# 1480  Result is outside the plausible range.
# 1483  Result is outside the plausible range.
# 1574  Result is outside the plausible range.
# 1580  Result is outside the plausible range.

# %% [markdown]
# ## 4. Anomaly Detection: The AI Detective (Level 2)
#
# The Sentry is good at catching values that are biologically impossible. Now, we will build an "AI Detective" to catch values that are **statistically improbable**. We will use an unsupervised machine learning algorithm called **Isolation Forest**. This algorithm is excellent at finding outliers in data.
#
# **Methodology:**
# 1.  **Feature Engineering:** Prepare the data for the model.
# 2.  **Model Training:** Train the Isolation Forest model on the "normal" data.
# 3.  **Prediction:** Use the trained model to predict which data points are anomalies.
# 4.  **Reporting:** Display the records that the AI has flagged as suspicious.

# %%
from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import StandardScaler

def find_statistical_anomalies(df: pd.DataFrame) -> pd.DataFrame:
    """
    Uses the Isolation Forest algorithm to find statistical anomalies.
    It analyzes each test type independently.

    Args:
        df (pd.DataFrame): The cleaned input DataFrame.

    Returns:
        pd.DataFrame: A DataFrame containing records flagged as statistical anomalies.
    """
    all_anomalies = []
    
    # We will run the model on each test type separately for better accuracy
    for test_name in df['test_name'].unique():
        df_test = df[df['test_name'] == test_name].copy()
        
        # The model needs at least 2 data points to run
        if len(df_test) < 2:
            continue
            
        # 1. Feature Engineering: We only need the numeric result
        # We need to reshape it because the model expects a 2D array
        X = df_test[['result_numeric']].values
        
        # 2. Model Training
        # contamination='auto' is a smart way to let the model decide the threshold for anomalies
        model = IsolationForest(contamination='auto', random_state=42)
        model.fit(X)
        
        # 3. Prediction
        # The model predicts -1 for anomalies and 1 for normal data
        df_test['anomaly_score'] = model.predict(X)
        
        # Filter for the anomalies
        anomalies = df_test[df_test['anomaly_score'] == -1]
        
        if not anomalies.empty:
            all_anomalies.append(anomalies)
            
    if not all_anomalies:
        return pd.DataFrame()
        
    # Combine all found anomalies into a single DataFrame
    final_anomalies_df = pd.concat(all_anomalies)
    
    # Prepare a clean report
    final_anomalies_df['reason'] = 'Result is a statistical outlier compared to other reports.'
    report_columns = {
        'source_file': 'Source File',
        'test_name': 'Test Name',
        'result_numeric': 'Anomalous Result',
        'reason': 'Reason'
    }
    return final_anomalies_df[list(report_columns.keys())].rename(columns=report_columns)

# --- EXECUTION ---
print("\n--- 🤖 Deploying The AI Detective... ---")
# We use the same 'master_df' that has already been cleaned
statistical_anomalies_df = find_statistical_anomalies(master_df)

if not statistical_anomalies_df.empty:
    print(f"\n--- 🕵️ AI Detective has flagged {len(statistical_anomalies_df)} records! ---")
    display(statistical_anomalies_df)
else:
    print("\n--- ✅ AI Detective reports: All clear! No statistical anomalies found. ---")
# Out:
# --- 🤖 Deploying The AI Detective... ---
#
# --- 🕵️ AI Detective has flagged 236 records! ---
#                                             Source File                    Test Name  Anomalous Result  \
# 126   ilide.info-blood-report-yatendra-08112022-pr_f...     Packed Cell Volume (PCV)              52.1
# 390                                             HDL.pdf     Packed Cell Volume (PCV)              33.0
# 336   ilide.info-max-lab-report-pr_37cb37b89df9e8ada...                          MCH              32.9
# 568   ilide.info-lab-report-sample-blood-pr_abc0d047...                          MCH              24.0
# 619   ilide.info-blood-report-pr_0f79618c92430ffd441...                          MCH              20.0
# ...                                                 ...                          ...               ...
# 1125  ilide.info-11-discharge-summary-pr_a8fd819c803...                         UREA              27.0
# 1109  ilide.info-11-discharge-summary-pr_a8fd819c803...             SERUM CREATININE               0.6
# 1110  ilide.info-11-discharge-summary-pr_a8fd819c803...                         eGFR             122.0
# 1123  ilide.info-11-discharge-summary-pr_a8fd819c803...                      D DIMER               0.3
# 1105  ilide.info-11-discharge-summary-pr_a8fd819c803...  RPG (RANDOM PLASMA GLUCOSE)             284.0
#
#                                                  Reason
# 126   Result is a statistical outlier compared to ot...
# 390   Result is a statistical outlier compared to ot...
# 336   Result is a statistical outlier compared to ot...
# 568   Result is a statistical outlier compared to ot...
# 619   Result is a statistical outlier compared to ot...
# ...                                                 ...
# 1125  Result is a statistical outlier compared to ot...
# 1109  Result is a statistical outlier compared to ot...
# 1110  Result is a statistical outlier compared to ot...
# 1123  Result is a statistical outlier compared to ot...
# 1105  Result is a statistical outlier compared to ot...
#
# [236 rows x 4 columns]
